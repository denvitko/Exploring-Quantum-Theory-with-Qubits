# %% [markdown]
# # Runs on Noisy Simulator for $H_1$, $H_2$ and $H_3$ - without mitigation

# %%
# %run ../SETUP/init.ipynb
# %run ../CLASSES/EXP-noisy-simulator.ipynb

# %% [markdown]
# ## Run for $H_1$ on Noisy Simulator - without mitigation

# %%
NOISY_H1 = NoisySimulator(HAMILTONIANS[0], backend_simulator, "NOISY_H1")
print(NOISY_H1)
NOISY_H1.run(noisy_simulator_runs, False)
display(NOISY_H1.data)
NOISY_H1.export_data("H1-without-mitigation")
NOISY_H1.plot("H1-theoretical-analyzis", True, False, theme='_classic_test_patch', save=[True, "H1-without-mitigation-0"])
NOISY_H1.plot("H1-theoretical-analyzis", False, True, theme='_classic_test_patch', save=[True, "H1-without-mitigation-1"])
NOISY_H1.plot("H1-theoretical-analyzis", True, True, theme='_classic_test_patch', save=[True, "H1-without-mitigation"])
# Out:
# ~ Experiment  for HAMILTONIAN 1 ~ NOISY_SIMULATOR
# --------------------------------------------------------
# Hamiltonian: [71. +0.j  0.+50.j][ 0.-50.j 71. +0.j]
# Eigenvalues difference: (100+0j)
# Time of evolution: 6.62607015e-36
#
# ---
# > experiment  successfully finished 🎉
# ---
#               point-1  point-2  point-3  point-4   point-5  point-6   point-7  \
# ZERO run-1   0.991000  0.98600  0.97300  0.95300  0.926000   0.8950  0.854000
#      run-2   0.989000  0.98500  0.97400  0.95400  0.931000   0.8930  0.853000
#      run-3   0.991000  0.98300  0.97000  0.95600  0.925000   0.8950  0.855000
#      run-4   0.990000  0.98400  0.97100  0.95300  0.924000   0.8980  0.858000
#      run-5   0.991000  0.98400  0.97100  0.95500  0.921000   0.9010  0.855000
#      run-6   0.988000  0.98400  0.97100  0.95000  0.924000   0.8860  0.847000
#      run-7   0.988000  0.98500  0.97200  0.95600  0.926000   0.8890  0.856000
# ...

# %% [markdown]
# ## Run for $H_2$ on Noisy Simulator - without mitigation

# %%
NOISY_H2 = NoisySimulator(HAMILTONIANS[1], backend_simulator, "NOISY_H2")
print(NOISY_H2)
NOISY_H2.run(noisy_simulator_runs, False)
display(NOISY_H2.data)
NOISY_H2.export_data("H2-without-mitigation")
NOISY_H2.plot("H2-theoretical-analyzis", True, False, theme='_classic_test_patch', save=[True, "H2-without-mitigation-0"])
NOISY_H2.plot("H2-theoretical-analyzis", False, True, theme='_classic_test_patch', save=[True, "H2-without-mitigation-1"])
NOISY_H2.plot("H2-theoretical-analyzis", True, True, theme='_classic_test_patch', save=[True, "H2-without-mitigation"])
# Out:
# ~ Experiment  for HAMILTONIAN 2 ~ NOISY_SIMULATOR
# --------------------------------------------------------
# Hamiltonian: [3.2+0.j 0.3+0.j][0.3 +0.j 4.16+0.j]
# Eigenvalues difference: (1.1320777358467924+0j)
# Time of evolution: 5.853016926477853e-34
#
# ---
# > experiment  successfully finished 🎉
# ---
#               point-1  point-2  point-3  point-4  point-5  point-6  point-7  \
# ZERO run-1   0.988000   0.9860  0.98500  0.98300  0.96900  0.96300  0.95300
#      run-2   0.990000   0.9870  0.98200  0.98100  0.97000  0.96100  0.94900
#      run-3   0.989000   0.9870  0.98400  0.97600  0.97300  0.96000  0.94900
#      run-4   0.988000   0.9880  0.98400  0.97400  0.96900  0.95800  0.94600
#      run-5   0.990000   0.9870  0.98300  0.97800  0.97100  0.95800  0.95000
#      run-6   0.988000   0.9870  0.98700  0.97800  0.97100  0.96200  0.95000
#      run-7   0.989000   0.9860  0.98300  0.97900  0.97200  0.96200  0.95000
# ...

# %% [markdown]
# ## Run for $H_3$ on Noisy Simulator - without mitigation

# %%
NOISY_H3 = NoisySimulator(HAMILTONIANS[2], backend_simulator, "NOISY_H3")
print(NOISY_H3)
NOISY_H3.run(noisy_simulator_runs, False)
display(NOISY_H3.data)
NOISY_H3.export_data("H3-without-mitigation")
NOISY_H3.plot("H3-theoretical-analyzis", True, False, theme='_classic_test_patch', save=[True, "H3-without-mitigation-0"])
NOISY_H3.plot("H3-theoretical-analyzis", False, True, theme='_classic_test_patch', save=[True, "H3-without-mitigation-1"])
NOISY_H3.plot("H3-theoretical-analyzis", True, True, theme='_classic_test_patch', save=[True, "H3-without-mitigation"])
# Out:
# ~ Experiment  for HAMILTONIAN 3 ~ NOISY_SIMULATOR
# --------------------------------------------------------
# Hamiltonian: [5.+0.j 3.+2.j][3.-2.j 5.+0.j]
# Eigenvalues difference: (7.211102550927978+0j)
# Time of evolution: 9.188706031017834e-35
#
# ---
# > experiment  successfully finished 🎉
# ---
#              point-1  point-2  point-3   point-4  point-5   point-6  point-7  \
# ZERO run-1   0.98900  0.98500  0.97200  0.951000  0.93100  0.891000  0.85100
#      run-2   0.98900  0.98300  0.97400  0.953000  0.92700  0.887000  0.85300
#      run-3   0.98800  0.98600  0.97200  0.954000  0.93200  0.890000  0.84900
#      run-4   0.98700  0.98300  0.97200  0.953000  0.92700  0.891000  0.85100
#      run-5   0.98900  0.98500  0.97100  0.953000  0.92300  0.894000  0.85500
#      run-6   0.99000  0.98500  0.97000  0.955000  0.92900  0.891000  0.85400
#      run-7   0.98800  0.98500  0.97500  0.952000  0.92700  0.896000  0.85500
# ...

# %% [markdown]
# ---

# %%
# print("... running of {noisy-simulator.ipynb}  successfully finished \U0001F389")
