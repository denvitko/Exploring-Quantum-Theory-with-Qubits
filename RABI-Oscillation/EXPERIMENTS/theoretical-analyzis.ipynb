# %% [markdown]
# # Theoretical Analyzis for $H_1$, $H_2$ and $H_3$

# %%
# %run ../SETUP/init.ipynb
# %run ../CLASSES/EXP-theoretical-analyzis.ipynb

# %% [markdown]
# ## Theoretical Analyzis for $H_1$

# %%
THEORY_H1 = TheoreticalAnalyzis(HAMILTONIANS[0], "THEORY_H1")
print(THEORY_H1)
THEORY_H1.run()
display(THEORY_H1.data)
THEORY_H1.export_data("H1-theoretical-analyzis")
THEORY_H1.plot(theme='_classic_test_patch', save=[True, "H1-theoretical-analyzis"])
# Out:
# ~ Experiment THEORY_H1 for HAMILTONIAN 1 ~ THEORETICAL_ANALYZIS
# --------------------------------------------------------
# Hamiltonian: [71. +0.j  0.+50.j][ 0.-50.j 71. +0.j]
# Eigenvalues difference: (100+0j)
# Time of evolution: 6.62607015e-36
#
# ---
# > experiment THEORY_H1 successfully finished 🎉
# ---
#             point-1   point-2   point-3   point-4   point-5   point-6  \
# ZERO run-1      1.0  0.995895  0.983647  0.963458  0.935659  0.900707
# ONE  run-1      0.0  0.004105  0.016353  0.036542  0.064341  0.099293
#
#              point-7   point-8   point-9  point-10  ...  point-41  point-42  \
# ZERO run-1  0.859175  0.811745  0.759196  0.702392  ...  0.702392  0.759196
# ONE  run-1  0.140825  0.188255  0.240804  0.297608  ...  0.297608  0.240804
#
#             point-43  point-44  point-45  point-46  point-47  point-48  \
# ZERO run-1  0.811745  0.859175  0.900707  0.935659  0.963458  0.983647
# ONE  run-1  0.188255  0.140825  0.099293  0.064341  0.036542  0.016353
#
# ...

# %% [markdown]
# ## Theoretical Analyzis for $H_2$

# %%
THEORY_H2 = TheoreticalAnalyzis(HAMILTONIANS[1], "THEORY_H2")
print(THEORY_H2)
THEORY_H2.run()
display(THEORY_H2.data)
THEORY_H2.export_data("H2-theoretical-analyzis")
THEORY_H2.plot(theme='_classic_test_patch', save=[True, "H2-theoretical-analyzis"])
# Out:
# ~ Experiment THEORY_H2 for HAMILTONIAN 2 ~ THEORETICAL_ANALYZIS
# --------------------------------------------------------
# Hamiltonian: [3.2+0.j 0.3+0.j][0.3 +0.j 4.16+0.j]
# Eigenvalues difference: (1.1320777358467924+0j)
# Time of evolution: 5.853016926477853e-34
#
# ---
# > experiment THEORY_H2 successfully finished 🎉
# ---
#             point-1   point-2   point-3   point-4   point-5   point-6  \
# ZERO run-1      1.0  0.998847  0.995407  0.989735  0.981927  0.972109
# ONE  run-1      0.0  0.001153  0.004593  0.010265  0.018073  0.027891
#
#              point-7   point-8   point-9  point-10  ...  point-41  point-42  \
# ZERO run-1  0.960442  0.947119  0.932359  0.916402  ...  0.916402  0.932359
# ONE  run-1  0.039558  0.052881  0.067641  0.083598  ...  0.083598  0.067641
#
#             point-43  point-44  point-45  point-46  point-47  point-48  \
# ZERO run-1  0.947119  0.960442  0.972109  0.981927  0.989735  0.995407
# ...

# %% [markdown]
# ## Theoretical Analyzis for $H_3$

# %%
THEORY_H3 = TheoreticalAnalyzis(HAMILTONIANS[2], "THEORY_H3")
print(THEORY_H3)
THEORY_H3.run()
display(THEORY_H3.data)
THEORY_H3.export_data("H3-theoretical-analyzis")
THEORY_H3.plot(theme='_classic_test_patch', save=[True, "H3-theoretical-analyzis"])
# Out:
# ~ Experiment THEORY_H3 for HAMILTONIAN 3 ~ THEORETICAL_ANALYZIS
# --------------------------------------------------------
# Hamiltonian: [5.+0.j 3.+2.j][3.-2.j 5.+0.j]
# Eigenvalues difference: (7.211102550927978+0j)
# Time of evolution: 9.188706031017834e-35
#
# ---
# > experiment THEORY_H3 successfully finished 🎉
# ---
#             point-1   point-2   point-3   point-4   point-5   point-6  \
# ZERO run-1      1.0  0.995895  0.983647  0.963458  0.935659  0.900707
# ONE  run-1      0.0  0.004105  0.016353  0.036542  0.064341  0.099293
#
#              point-7   point-8   point-9  point-10  ...  point-41  point-42  \
# ZERO run-1  0.859175  0.811745  0.759196  0.702392  ...  0.702392  0.759196
# ONE  run-1  0.140825  0.188255  0.240804  0.297608  ...  0.297608  0.240804
#
#             point-43  point-44  point-45  point-46  point-47  point-48  \
# ZERO run-1  0.811745  0.859175  0.900707  0.935659  0.963458  0.983647
# ...

# %% [markdown]
# ---

# %%
# print("... running of {theoretical-analyzis.ipynb}  successfully finished \U0001F389")
