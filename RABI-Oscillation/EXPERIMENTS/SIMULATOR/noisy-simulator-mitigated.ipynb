# %% [markdown]
# # Runs on Noisy Simulator for $H_1$, $H_2$ and $H_3$ - with mitigation

# %%
# %run ../SETUP/init.ipynb
# %run ../CLASSES/EXP-noisy-simulator.ipynb

# %% [markdown]
# ## Run for $H_1$ on Noisy Simulator - with mitigation

# %%
MITIG_H1 = NoisySimulator(HAMILTONIANS[0], backend_simulator, "MITIG_H1")
print(MITIG_H1)
MITIG_H1.run(noisy_simulator_runs, True)
display(MITIG_H1.data)
MITIG_H1.export_data("H1-with-mitigation")
MITIG_H1.plot("H1-theoretical-analyzis", True, False, theme='_classic_test_patch', save=[True, "H1-with-mitigation-0"])
MITIG_H1.plot("H1-theoretical-analyzis", False, True, theme='_classic_test_patch', save=[True, "H1-with-mitigation-1"])
MITIG_H1.plot("H1-theoretical-analyzis", True, True, theme='_classic_test_patch', save=[True, "H1-with-mitigation"])
# Out:
# ~ Experiment MITIG_H1 for HAMILTONIAN 1 ~ NOISY_SIMULATOR
# --------------------------------------------------------
# Hamiltonian: [71. +0.j  0.+50.j][ 0.-50.j 71. +0.j]
# Eigenvalues difference: (100+0j)
# Time of evolution: 6.62607015e-36
#
# ---
# > experiment MITIG_H1 successfully finished 🎉
# ---
#               point-1  point-2  point-3  point-4  point-5   point-6  point-7  \
# ZERO run-1   0.999000  0.99600  0.98100  0.96200  0.93300  0.899000  0.85000
#      run-2   0.997000  0.99400  0.98200  0.95900  0.93500  0.896000  0.86300
#      run-3   0.998000  0.99500  0.98500  0.95900  0.93300  0.898000  0.85400
#      run-4   0.998000  0.99400  0.98500  0.95900  0.93100  0.899000  0.86200
#      run-5   0.999000  0.99300  0.97800  0.96100  0.92900  0.901000  0.85300
#      run-6   0.999000  0.99400  0.98200  0.95900  0.93800  0.896000  0.84900
#      run-7   1.000000  0.99400  0.97800  0.96100  0.93200  0.904000  0.85500
# ...

# %% [markdown]
# ## Run for $H_2$ on Noisy Simulator - with mitigation

# %%
MITIG_H2 = NoisySimulator(HAMILTONIANS[1], backend_simulator, "MITIG_H2")
print(MITIG_H2)
MITIG_H2.run(noisy_simulator_runs, True)
display(MITIG_H2.data)
MITIG_H2.export_data("H2-with-mitigation")
MITIG_H2.plot("H2-theoretical-analyzis", True, False, theme='_classic_test_patch', save=[True, "H2-with-mitigation-0"])
MITIG_H2.plot("H2-theoretical-analyzis", False, True, theme='_classic_test_patch', save=[True, "H2-with-mitigation-1"])
MITIG_H2.plot("H2-theoretical-analyzis", True, True, theme='_classic_test_patch', save=[True, "H2-with-mitigation"])
# Out:
# ~ Experiment MITIG_H2 for HAMILTONIAN 2 ~ NOISY_SIMULATOR
# --------------------------------------------------------
# Hamiltonian: [3.2+0.j 0.3+0.j][0.3 +0.j 4.16+0.j]
# Eigenvalues difference: (1.1320777358467924+0j)
# Time of evolution: 5.853016926477853e-34
#
# ---
# > experiment MITIG_H2 successfully finished 🎉
# ---
#              point-1  point-2  point-3  point-4  point-5  point-6  point-7  \
# ZERO run-1       1.0   1.0000  0.99700  0.99000  0.98100  0.97400    0.961
#      run-2       1.0   1.0000  0.99500  0.99100  0.98200  0.97700    0.958
#      run-3       1.0   0.9980  0.99700  0.99000  0.98200  0.97400    0.965
#      run-4       1.0   1.0000  0.99900  0.99100  0.98400  0.97600    0.960
#      run-5       1.0   0.9990  0.99600  0.98900  0.98700  0.97500    0.961
#      run-6       1.0   1.0000  0.99500  0.99100  0.98400  0.97000    0.960
#      run-7       1.0   1.0000  0.99400  0.98800  0.98200  0.97700    0.955
# ...

# %% [markdown]
# ## Run for $H_3$ on Noisy Simulator - with mitigation

# %%
MITIG_H3 = NoisySimulator(HAMILTONIANS[2], backend_simulator, "MITIG_H3")
print(MITIG_H3)
MITIG_H3.run(noisy_simulator_runs, True)
display(MITIG_H3.data)
MITIG_H3.export_data("H3-with-mitigation")
MITIG_H3.plot("H3-theoretical-analyzis", True, False, theme='_classic_test_patch', save=[True, "H3-with-mitigation-0"])
MITIG_H3.plot("H3-theoretical-analyzis", False, True, theme='_classic_test_patch', save=[True, "H3-with-mitigation-1"])
MITIG_H3.plot("H3-theoretical-analyzis", True, True, theme='_classic_test_patch', save=[True, "H3-with-mitigation"])
# Out:
# ~ Experiment MITIG_H3 for HAMILTONIAN 3 ~ NOISY_SIMULATOR
# --------------------------------------------------------
# Hamiltonian: [5.+0.j 3.+2.j][3.-2.j 5.+0.j]
# Eigenvalues difference: (7.211102550927978+0j)
# Time of evolution: 9.188706031017834e-35
#
# ---
# > experiment MITIG_H3 successfully finished 🎉
# ---
#              point-1   point-2  point-3  point-4   point-5  point-6  point-7  \
# ZERO run-1   0.99800  0.994000  0.97800  0.96100  0.928000   0.8920  0.85400
#      run-2   0.99700  0.993000  0.97500  0.96600  0.932000   0.8950  0.85900
#      run-3   0.99800  0.995000  0.98100  0.95900  0.926000   0.8990  0.86200
#      run-4   0.99900  0.994000  0.98400  0.95600  0.928000   0.8950  0.85400
#      run-5   0.99800  0.993000  0.97900  0.96000  0.931000   0.8910  0.85600
#      run-6   0.99800  0.994000  0.98000  0.95700  0.932000   0.9000  0.86400
#      run-7   1.00000  0.994000  0.97900  0.96100  0.933000   0.9000  0.84800
# ...

# %% [markdown]
# ---

# %%
# print("... running of {noisy-simulator.ipynb}  successfully finished \U0001F389")
